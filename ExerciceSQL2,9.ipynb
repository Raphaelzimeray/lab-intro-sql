# %% [markdown]
# # Exercice SQL 2.9

# %%
# !pip install pymysql
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 137.8 kB/s eta 0:00:00a 0:00:01
# ...

# %%
import pandas as pd
import numpy as np
import pymysql
from sqlalchemy import create_engine, text
import getpass

# %%
password = getpass.getpass()
# Out:
# ········

# %%
connection_string = 'mysql+pymysql://root:'+password+'@localhost/sakila'
engine = create_engine(connection_string)

# %%
#How many distinct (different) actors' last names are there?

query ="""SELECT count(distinct last_name)
FROM actor;"""
data1 = pd.read_sql_query(query, engine)
data1
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/anaconda3/lib/python3.10/site-packages/sqlalchemy/engine/base.py:3280, in Engine._wrap_pool_connect(self, fn, connection)
#    3279 try:
# -> 3280     return fn()
#    3281 except dialect.dbapi.Error as e:
#
# File ~/anaconda3/lib/python3.10/site-packages/sqlalchemy/pool/base.py:310, in Pool.connect(self)
#     303 """Return a DBAPI connection from the pool.
#     304
#     305 The connection is instrumented such that when its
#    (...)
#     308
#     309 """
# --> 310 return _ConnectionFairy._checkout(self)
#
# File ~/anaconda3/lib/python3.10/site-packages/sqlalchemy/pool/base.py:868, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     867 if not fairy:
# --> 868     fairy = _ConnectionRecord.checkout(pool)
#     870     fairy._pool = pool
#
# ...

# %%
password = getpass.getpass()
# Out:
# ········

# %%
password = getpass.getpass()
# Out:
# ········

# %%
connection_string = 'mysql+pymysql://root:'+password+'@localhost/sakila'
engine = create_engine(connection_string)

# %%
#How many distinct (different) actors' last names are there?

query ="""SELECT count(distinct last_name)
FROM actor;"""
data1 = pd.read_sql_query(query, engine)
data1
# Out:
#    count(distinct last_name)
# 0                        121

# %%
query_2 = """SELECT *,
    CASE
        WHEN DAYOFWEEK(rental_date) IN (1, 7) THEN 'weekend'
        ELSE 'workday'
    END AS day_type
FROM rental;"""
data2 = pd.read_sql_query(query_2, engine)
data2
# Out:
#        rental_id         rental_date  inventory_id  customer_id  \
# 0              1 2005-05-24 22:53:30           367          130
# 1              2 2005-05-24 22:54:33          1525          459
# 2              3 2005-05-24 23:03:39          1711          408
# 3              4 2005-05-24 23:04:41          2452          333
# 4              5 2005-05-24 23:05:21          2079          222
# ...          ...                 ...           ...          ...
# 16040      16046 2005-08-23 22:26:47          4364           74
# 16041      16047 2005-08-23 22:42:48          2088          114
# 16042      16048 2005-08-23 22:43:07          2019          103
# 16043      16049 2005-08-23 22:50:12          2666          393
# 16044      16050 2023-05-23 00:22:33             1          130
#
#               return_date  staff_id         last_update day_type
# 0     2005-05-26 22:04:30         1 2006-02-15 21:30:53  workday
# 1     2005-05-28 19:40:33         1 2006-02-15 21:30:53  workday
# ...

# %%
query_3 = """SELECT *
FROM film
WHERE title like '%%ARMAGEDDON%%';"""
data_3 = pd.read_sql_query(query_3, engine)
data_3
# Out:
#    film_id                  title  \
# 0       39        ARMAGEDDON LOST
# 1      507    LADYBUGS ARMAGEDDON
# 2      571       METAL ARMAGEDDON
# 3      598    MOSQUITO ARMAGEDDON
# 4      838  STAGECOACH ARMAGEDDON
# 5      844      STEERS ARMAGEDDON
#
#                                          description  release_year  \
# 0  A Fast-Paced Tale of a Boat And a Teacher who ...          2006
# 1  A Fateful Reflection of a Dog And a Mad Scient...          2006
# 2  A Thrilling Display of a Lumberjack And a Croc...          2006
# 3  A Thoughtful Character Study of a Waitress And...          2006
# 4  A Touching Display of a Pioneer And a Butler w...          2006
# 5  A Stunning Character Study of a Car And a Girl...          2006
#
#    language_id original_language_id  rental_duration  rental_rate  length  \
# 0            1                 None                5         0.99      99
# 1            1                 None                4         0.99     113
# ...

# %%
query_4 = """SELECT *
FROM film
ORDER BY length DESC LIMIT 10;"""
data_4 = pd.read_sql_query(query_4, engine)
data_4
# Out:
#    film_id               title  \
# 0      349         GANGS PRIDE
# 1      872   SWEET BROTHERHOOD
# 2      609       MUSCLE BRIGHT
# 3      817  SOLDIERS EVOLUTION
# 4      690        POND SEATTLE
# 5      141       CHICAGO NORTH
# 6      182      CONTROL ANTHEM
# 7      991        WORST BANGER
# 8      426           HOME PITY
# 9      212      DARN FORRESTER
#
#                                          description  release_year  \
# 0  A Taut Character Study of a Woman And a A Shar...          2006
# 1  A Unbelieveable Epistle of a Sumo Wrestler And...          2006
# 2  A Stunning Panorama of a Sumo Wrestler And a H...          2006
# 3  A Lacklusture Panorama of a A Shark And a Pion...          2006
# 4  A Stunning Drama of a Teacher And a Boat who m...          2006
# 5  A Fateful Yarn of a Mad Cow And a Waitress who...          2006
# 6  A Fateful Documentary of a Robot And a Student...          2006
# 7  A Thrilling Drama of a Madman And a Dentist wh...          2006
# ...

# %%
query_5 = """SELECT COUNT(*)
FROM film
WHERE special_features like '%%Behind the Scenes%%';"""
data_5 = pd.read_sql_query(query_5, engine)
data_5
# Out:
#    COUNT(*)
# 0       538

# %%
query_6 = """SELECT rating, AVG(length) AS avg_duration
FROM film
GROUP BY rating
HAVING AVG(length) > 120;"""
data_6 =  pd.read_sql_query(query_6, engine)
data_6
# Out:
#   rating  avg_duration
# 0  PG-13      120.4439

# %%
query_7 = """SELECT DENSE_RANK() OVER(ORDER BY length DESC) as 'Rank', title, length
FROM film
WHERE length != 0 and length IS NOT NULL;"""
data_7 = pd.read_sql_query(query_7, engine)
data_7
# Out:
#      Rank                title  length
# 0       1        CHICAGO NORTH     185
# 1       1       CONTROL ANTHEM     185
# 2       1       DARN FORRESTER     185
# 3       1          GANGS PRIDE     185
# 4       1            HOME PITY     185
# ..    ...                  ...     ...
# 995   140         ALIEN CENTER      46
# 996   140            IRON MOON      46
# 997   140        KWAI HOMEWARD      46
# 998   140     LABYRINTH LEAGUE      46
# 999   140  RIDGEMONT SUBMARINE      46
#
# [1000 rows x 3 columns]

# %% [markdown]
# # End of the exercice
